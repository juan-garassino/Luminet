# %%
from luminet.luminet.plotting import generate_image, generate_isoradials, generate_scatter_image

import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from luminet.luminet.plotting import generate_image, generate_isoradials, generate_scatter_image
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'luminet'

# %%
th0 = 80
alpha = np.linspace(0, 2*np.pi, 750)
r_vals = np.arange(7, 29, 0.5)
n_vals = [0]
m = 1

fig = generate_scatter_image(None, alpha, r_vals, th0, n_vals, m, None);
