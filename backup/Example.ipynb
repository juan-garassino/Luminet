# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import bh as bh
import sympy as sy
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import cmocean.cm as ccm
import matplotlib.transforms as mt
import scipy.interpolate as si
import out as out
plt.style.use('dark_background')

# %%
th0 = 80
alpha = np.linspace(0, 2*np.pi, 1000)
r_vals = np.arange(6, 60, 0.5)
n_vals = [0, 1]
m = 1

fix, ax = plt.subplots(figsize=(40, 40))
fig = out.generate_image(ax, alpha, r_vals, th0, n_vals, m, None);

# %%
fig.savefig('blackhole.png', dpi=300)

# %%
th0 = 80
alpha = np.linspace(0, 2*np.pi, 100)
r_vals = np.arange(7, 29, 0.5)
n_vals = [0, 1, 2]
m = 1

# fix, ax = plt.subplots(figsize=(40, 40))

fig = out.generate_isoradials(th0, r_vals, n_vals);

# %%
fig.savefig('blackhole_isoradials.png', dpi=300)

# %%
th0 = 80
alpha = np.linspace(0, 2*np.pi, 750)
r_vals = np.arange(7, 29, 0.5)
n_vals = [0]
m = 1

fig = out.generate_scatter_image(None, alpha, r_vals, th0, n_vals, m, None);

# %%
fig.savefig('blackhole_scatter.png', dpi=300)
